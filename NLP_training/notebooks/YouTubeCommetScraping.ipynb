# %%
# !pip install emoji

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyAmBkakp9o3OuZgpjNzSrRIPR3iMF5y7nQ"

# %%
comments = []

# %%
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
def fill_comment_by_YT(videoIdINPUT):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId= videoIdINPUT,
      maxResults=100
  )


  response = request.execute()

  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['textOriginal'],
        public
    ])

  while (1):
    try:
      nextPageToken = response['nextPageToken']
    except KeyError:
      break
    nextPageToken = response['nextPageToken']

    nextRequest = youtube.commentThreads().list(
      part="snippet",
      videoId="ft9MTPDwrHs",
      maxResults=100,
      pageToken=nextPageToken
    )

    response = nextRequest.execute()

    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
        comment['textOriginal'],
        public
      ])

# %%
video_ids = [
    "6Iz2xLNSxwE",
    "v3G2kPhq77c",
    "Iaq0feB8pqI",
    "7VbzL_ONE0k",
    "kMkYRkEAsaY",
    "Gwz8ug8ZvgU",
    "OpEceC7bb9o"
]
for id in video_ids:
  fill_comment_by_YT(id)

# %%
df = pd.DataFrame(comments, columns=['comment' , 'public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4515 entries, 0 to 4514
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   comment  4515 non-null   object
#  1   public   4515 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 39.8+ KB

# %%
df = df[df['comment'].str.len() >= 10]

# %%
df.shape
# Out:
# (3829, 2)

# %%
df.head(20)
# Out:
#                                               comment  public
# 2               Aththatama ledakda kohedo appa paw😢😂😂    True
# 3                   Inoka akka wenna hadanawada mnda😅    True
# 4   Me kettu kaleda bn.den mahath wela nisa lassan...    True
# 5   Mn tea genwa hmotma bnna ☕☕☕☕☕☕☕☕☕☕☕☕☕☕☕☕☕☕me ...    True
# 6   කෝ මම වගේ දාපු comments බලන්න ආපු අය.......😂😂😂...    True
# 7                            Inna hati gahanna හිතනවා    True
# 8                                         Kotu hutti😂    True
# 9                                      මගේ නම   නිශදි    True
# 11                                     Kakka danawada    True
# 12  මෙකි නිසා ලංකාවේ ලමයි හදාගන්න බැරිවෙනවා මෙයට ක...    True
# 13  Meki kalema vade karanna yanne yako vasikiliya...    True
# 15  මේ එළදෙනට පිස්සු වැඩි වෙලා මේ උන් ඉන්න කොට රට‍...    True
# 16               මම හිතුවෙ කොමඩ් එකක ඉන්නේ කියලා 😂😂😂😂    True
# 17                                   Chik munge heti😢    True
# ...

# %%
import emoji

def remove_emoji(text):
  return emoji.replace_emoji(text, replace='')

# %%
df['comment'] = df['comment'].apply(remove_emoji)
df.head()
# Out:
#                                              comment  public
# 2                 Aththatama ledakda kohedo appa paw    True
# 3                   Inoka akka wenna hadanawada mnda    True
# 4  Me kettu kaleda bn.den mahath wela nisa lassan...    True
# 5  Mn tea genwa hmotma bnna me wge pissiyk blnna ...    True
# 6        කෝ මම වගේ දාපු comments බලන්න ආපු අය.......    True

# %%
df = df[df['comment'].str.len() > 10]
df.shape
# Out:
# (3641, 2)

# %%
def remove_p (text):
  text = text.replace('.', '')
  text = text.replace(',', '')
  text = text.replace('!', '')
  text = text.replace('?', '')
  text = text.replace(':', '')
  text = text.replace(';', '')
  return text

df['comment'] = df['comment'].apply(remove_p)

# %%
df.head(10)
# Out:
#                                               comment  public
# 2                  Aththatama ledakda kohedo appa paw    True
# 3                    Inoka akka wenna hadanawada mnda    True
# 4    Me kettu kaleda bnden mahath wela nisa lassanayi    True
# 5   Mn tea genwa hmotma bnna me wge pissiyk blnna ...    True
# 6                කෝ මම වගේ දාපු comments බලන්න ආපු අය    True
# 7                            Inna hati gahanna හිතනවා    True
# 9                                      මගේ නම   නිශදි    True
# 11                                     Kakka danawada    True
# 12  මෙකි නිසා ලංකාවේ ලමයි හදාගන්න බැරිවෙනවා මෙයට ක...    True
# 13  Meki kalema vade karanna yanne yako vasikiliya...    True

# %%
df.to_csv('/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/videomix1_comments.csv', index=False)

# %%
## Lets get the Previous saved csv files and merge and remove repeated data

import pandas as pd
import glob

csv_files = glob.glob("/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/*.csv")

print(csv_files)
# Out:
# ['/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/Dinithi_comments.csv', '/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/KeheliyaVideo_comments.csv', '/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/videomix_comments.csv', '/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/videomix1_comments.csv']

# %%
df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

df.head()
# Out:
#                                              comment  public
# 0  Nodakin me wage harak bolada wenna hadanva upa...    True
# 1                                      Mala samayegn    True
# 2                                     Nodakin vikara    True
# 3                        Nodakin thopi thoththa baba    True
# 4   අම්මේ පඩ සෝ  මේකිගේ  මට‍ නම් පේන්න බැ ගොන් බඩුව     True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7074 entries, 0 to 7073
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   comment  7074 non-null   object
#  1   public   7074 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 62.3+ KB

# %%
df.drop_duplicates(subset=['comment'], keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1531 entries, 0 to 7073
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   comment  1531 non-null   object
#  1   public   1531 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 25.4+ KB

# %%
df.head()
# Out:
#                                              comment  public
# 0  Nodakin me wage harak bolada wenna hadanva upa...    True
# 1                                      Mala samayegn    True
# 2                                     Nodakin vikara    True
# 3                        Nodakin thopi thoththa baba    True
# 4   අම්මේ පඩ සෝ  මේකිගේ  මට‍ නම් පේන්න බැ ගොන් බඩුව     True

# %%
df.to_csv('/content/drive/MyDrive/Dataset/ScrappedCommentYoutube/comment_1st_set.csv', index=False)
